# %%
# Load the necessary libraries needed for analysis
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use("seaborn")

# %% [markdown]
# ## Titles dataset

# %%
# load the dataset into a dataframe

df_titles = pd.read_csv('Netflix_titles.csv')
df_titles.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# 4  12-year-old Regan MacNeil begins to adapt an e...          1973
#
#   age_certification  runtime                 genres production_countries  \
# 0             TV-MA       48      ['documentation']               ['US']
# 1                 R      113     ['crime', 'drama']               ['US']
# 2                PG       91  ['comedy', 'fantasy']               ['GB']
# 3                 R       94             ['comedy']               ['GB']
# 4                 R      133             ['horror']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0      1.0        NaN         NaN         NaN            0.600         NaN
# 1      NaN  tt0075314         8.3    795222.0           27.612         8.2
# 2      NaN  tt0071853         8.2    530877.0           18.216         7.8
# 3      NaN  tt0079470         8.0    392419.0           17.505         7.8
# 4      NaN  tt0070047         8.1    391942.0           95.337         7.7

# %%
# details of the dataset

print(df_titles.shape)
df_titles.describe()
# Out:
# (5806, 15)
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5806.000000  5806.000000  2047.000000  5283.000000  5.267000e+03
# mean    2016.013434    77.643989     2.165608     6.533447  2.340719e+04
# std        7.324883    39.474160     2.636207     1.160932  8.713432e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2015.000000    44.000000     1.000000     5.800000  5.210000e+02
# 50%     2018.000000    84.000000     1.000000     6.600000  2.279000e+03
# 75%     2020.000000   105.000000     2.000000     7.400000  1.014400e+04
# max     2022.000000   251.000000    42.000000     9.600000  2.268288e+06
#
#        tmdb_popularity   tmdb_score
# count      5712.000000  5488.000000
# mean         22.525660     6.818039
# std          68.849177     1.171560
# min           0.009442     0.500000
# 25%           3.155250     6.100000
# 50%           7.478000     6.900000
# 75%          17.775750     7.500000
# max        1823.374000    10.000000

# %%
# data information and datatype

df_titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5806 entries, 0 to 5805
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5806 non-null   object
#  1   title                 5805 non-null   object
#  2   type                  5806 non-null   object
#  3   description           5788 non-null   object
#  4   release_year          5806 non-null   int64
#  5   age_certification     3196 non-null   object
#  6   runtime               5806 non-null   int64
#  7   genres                5806 non-null   object
#  8   production_countries  5806 non-null   object
#  9   seasons               2047 non-null   float64
#  10  imdb_id               5362 non-null   object
#  11  imdb_score            5283 non-null   float64
#  12  imdb_votes            5267 non-null   float64
#  13  tmdb_popularity       5712 non-null   float64
#  14  tmdb_score            5488 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 680.5+ KB

# %%
# check for duplicates in the dataset
df_titles.duplicated().sum()
# Out:
# 0

# %%
# check for null values
df_titles.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2610
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3759
# imdb_id                  444
# imdb_score               523
# imdb_votes               539
# tmdb_popularity           94
# tmdb_score               318
# dtype: int64

# %% [markdown]
# ### Data cleansing

# %%
# remove columns that are not essential to this analysis
# data.drop(['description', 'imdb_id', 'imdb_votes', 'imdb_score'], axis=1, inplace = True)

# %%
# remove rows with missing values

# %% [markdown]
# ## Credits Dataset

# %%
# load the dataset into a dataframe

df_credits = pd.read_csv('Netflix_credits.csv')
df_credits.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
# details of the dataset

print(df_credits.shape)
df_credits.describe()
# Out:
# (77213, 5)
#           person_id
# count  7.721300e+04
# mean   4.994603e+05
# std    6.128431e+05
# min    7.000000e+00
# 25%    4.158400e+04
# 50%    1.829850e+05
# 75%    8.415570e+05
# max    2.371585e+06

# %%
# data information and datatype

df_credits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77213 entries, 0 to 77212
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   person_id  77213 non-null  int64
#  1   id         77213 non-null  object
#  2   name       77213 non-null  object
#  3   character  67586 non-null  object
#  4   role       77213 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 2.9+ MB

# %%
# check for duplicates in the dataset
df_credits.duplicated().sum()
# Out:
# 0

# %%
# check for null values
df_credits.isnull().sum()
# Out:
# person_id       0
# id              0
# name            0
# character    9627
# role            0
# dtype: int64

# %% [markdown]
# ## Merging both the datasets

# %%
df_titles_credits = pd.merge(df_titles, df_credits, how='outer', on='id')

# %%
df_titles_credits.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2   tm84618                          Taxi Driver  MOVIE
# 3   tm84618                          Taxi Driver  MOVIE
# 4   tm84618                          Taxi Driver  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  A mentally unstable Vietnam War veteran works ...          1976
# 3  A mentally unstable Vietnam War veteran works ...          1976
# 4  A mentally unstable Vietnam War veteran works ...          1976
#
#   age_certification  runtime              genres production_countries  \
# 0             TV-MA       48   ['documentation']               ['US']
# 1                 R      113  ['crime', 'drama']               ['US']
# 2                 R      113  ['crime', 'drama']               ['US']
# 3                 R      113  ['crime', 'drama']               ['US']
# 4                 R      113  ['crime', 'drama']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 0      1.0        NaN         NaN         NaN            0.600         NaN
# 1      NaN  tt0075314         8.3    795222.0           27.612         8.2
# 2      NaN  tt0075314         8.3    795222.0           27.612         8.2
# 3      NaN  tt0075314         8.3    795222.0           27.612         8.2
# 4      NaN  tt0075314         8.3    795222.0           27.612         8.2
#
#    person_id            name                character   role
# 0        NaN             NaN                      NaN    NaN
# 1     3748.0  Robert De Niro            Travis Bickle  ACTOR
# 2    14658.0    Jodie Foster            Iris Steensma  ACTOR
# 3     7064.0   Albert Brooks                      Tom  ACTOR
# 4     3739.0   Harvey Keitel  Matthew 'Sport' Higgins  ACTOR

# %%
df_titles_credits.shape
# Out:
# (77585, 19)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
# count for each type

sns.countplot(data=df_titles, x='type')
plt.show()

# %%
df_titles.type.value_counts().plot(kind='pie', figsize=(10, 5), autopct='%1.1f%%')
plt.title('Type distribution')
plt.show()

# %% [markdown]
# Looks like the dataset has more movie data than show data

# %%
# count by release year

sns.lineplot(data=df_titles.release_year.value_counts())
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
df_titles['release_year'].hist(figsize=(10, 5));

# %% [markdown]
# Looks like the dataset has more data for recent years <br>
# OR <br>
# there is a huge increase of production between 2010 and 2020

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ### Top 10 countries with highest production

# %%
top_10_countries = df_titles.production_countries.value_counts().head(10)

top_10_countries.plot(kind = 'bar', width =0.8, figsize=(9, 6), color='g')
plt.title('Top 10 countries with highest production')
plt.xlabel('Countries')
plt.ylabel('Production count')
plt.show()

# %% [markdown]
# US has highest number of production, followed by IN

# %% [markdown]
# ### Top 10 directors based on tmdb popularity

# %%
directors = df_titles_credits[df_titles_credits.role == 'DIRECTOR']
directors.head()
# Out:
#            id                            title   type  \
# 37    tm84618                      Taxi Driver  MOVIE
# 84   tm127384  Monty Python and the Holy Grail  MOVIE
# 85   tm127384  Monty Python and the Holy Grail  MOVIE
# 107   tm70993                    Life of Brian  MOVIE
# 149  tm190788                     The Exorcist  MOVIE
#
#                                            description  release_year  \
# 37   A mentally unstable Vietnam War veteran works ...          1976
# 84   King Arthur, accompanied by his squire, recrui...          1975
# 85   King Arthur, accompanied by his squire, recrui...          1975
# 107  Brian Cohen is an average young Jewish man, bu...          1979
# 149  12-year-old Regan MacNeil begins to adapt an e...          1973
#
#     age_certification  runtime                 genres production_countries  \
# 37                  R      113     ['crime', 'drama']               ['US']
# 84                 PG       91  ['comedy', 'fantasy']               ['GB']
# 85                 PG       91  ['comedy', 'fantasy']               ['GB']
# 107                 R       94             ['comedy']               ['GB']
# 149                 R      133             ['horror']               ['US']
#
#      seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score  \
# 37       NaN  tt0075314         8.3    795222.0           27.612         8.2
# 84       NaN  tt0071853         8.2    530877.0           18.216         7.8
# 85       NaN  tt0071853         8.2    530877.0           18.216         7.8
# 107      NaN  tt0079470         8.0    392419.0           17.505         7.8
# 149      NaN  tt0070047         8.1    391942.0           95.337         7.7
#
#      person_id              name character      role
# 37      3308.0   Martin Scorsese       NaN  DIRECTOR
# 84     11475.0       Terry Jones       NaN  DIRECTOR
# 85     11473.0     Terry Gilliam       NaN  DIRECTOR
# 107    11475.0       Terry Jones       NaN  DIRECTOR
# 149    14255.0  William Friedkin       NaN  DIRECTOR

# %%
top_10_directors = directors.sort_values(['tmdb_score', 'tmdb_popularity'], ascending=False)[['name', 'tmdb_score','tmdb_popularity']].head(10)
top_10_directors
# Out:
#                       name  tmdb_score  tmdb_popularity
# 27356           tooniverse        10.0           13.649
# 69480          Alex Cabral        10.0            7.430
# 27540         Shin Tae sik        10.0            6.616
# 64697  Peerapol Kirdjareun        10.0            6.550
# 64270            Fabio Ock        10.0            4.847
# 40624             Ding Pei        10.0            4.179
# 72972          Phil Allora        10.0            3.669
# 72973          Jae Woo Kim        10.0            3.669
# 64963  Donnie Lai Cheun-Yu        10.0            3.412
# 75964         Rick Suvalle        10.0            2.398

# %%
top_10_directors.plot(kind= 'barh', y = 'tmdb_popularity', x = 'name', figsize= (9,6), color= 'blue')
plt.xlabel('tmdb popularity')
plt.ylabel('name')
plt.title('Top 10 directors based on tmdb popularity')
plt.show()

# %% [markdown]
# ### Get top 5 movies and shows by genre

# %%
df_titles.genres.value_counts()
# Out:
# ['comedy']                                                                           510
# ['drama']                                                                            350
# ['documentation']                                                                    320
# ['comedy', 'drama']                                                                  141
# ['drama', 'comedy']                                                                  128
#                                                                                     ...
# ['drama', 'romance', 'history', 'war']                                                 1
# ['scifi', 'drama', 'action', 'thriller', 'horror', 'romance', 'crime', 'fantasy']      1
# ['drama', 'fantasy', 'horror', 'thriller', 'crime']                                    1
# ['fantasy', 'animation', 'action', 'family']                                           1
# ['drama', 'action', 'romance']                                                         1
# Name: genres, Length: 1626, dtype: int64

# %%
## TBD

# %% [markdown]
# ## Visualize data for movies

# %%
movies = df_titles[df_titles.type == 'MOVIE'][['release_year', 'runtime', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']]
movies
# Out:
#       release_year  runtime  imdb_score  imdb_votes  tmdb_popularity  \
# 1             1976      113         8.3    795222.0           27.612
# 2             1975       91         8.2    530877.0           18.216
# 3             1979       94         8.0    392419.0           17.505
# 4             1973      133         8.1    391942.0           95.337
# 6             1971      102         7.7    153463.0           14.745
# ...            ...      ...         ...         ...              ...
# 5800          2021      108         5.8        26.0            4.112
# 5801          2021      100         6.9        39.0            0.966
# 5802          2021       74         NaN         NaN            1.036
# 5803          2021       88         6.5        32.0            0.709
# 5804          2021      116         6.2         9.0            2.186
#
#       tmdb_score
# 1            8.2
# 2            7.8
# 3            7.8
# 4            7.7
# 6            7.5
# ...          ...
# 5800         NaN
# 5801         NaN
# 5802         8.5
# 5803         NaN
# 5804         NaN
#
# [3759 rows x 6 columns]

# %%
movies.hist(figsize=(10, 10))
# Out:
# array([[<AxesSubplot:title={'center':'release_year'}>,
#         <AxesSubplot:title={'center':'runtime'}>],
#        [<AxesSubplot:title={'center':'imdb_score'}>,
#         <AxesSubplot:title={'center':'imdb_votes'}>],
#        [<AxesSubplot:title={'center':'tmdb_popularity'}>,
#         <AxesSubplot:title={'center':'tmdb_score'}>]], dtype=object)

# %% [markdown]
# ### Compare Show votings between IMDB and TMDB over the years

# %%
shows = df_titles[df_titles.type == 'SHOW'][['release_year', 'imdb_score', 'tmdb_score']]
shows
# Out:
#       release_year  imdb_score  tmdb_score
# 0             1945         NaN         NaN
# 5             1969         8.8         8.3
# 29            1972         8.1         7.0
# 47            1989         8.9         8.3
# 55            1982         6.9         7.5
# ...            ...         ...         ...
# 5793          2021         NaN         NaN
# 5794          2021         NaN         8.0
# 5796          2021         4.6         6.0
# 5799          2021         NaN         NaN
# 5805          2021         8.8        10.0
#
# [2047 rows x 3 columns]

# %%
shows.dropna(axis=0, subset=['imdb_score', 'tmdb_score'], inplace=True)
shows
# Out:
#       release_year  imdb_score  tmdb_score
# 5             1969         8.8         8.3
# 29            1972         8.1         7.0
# 47            1989         8.9         8.3
# 55            1982         6.9         7.5
# 57            1984         6.5         6.6
# ...            ...         ...         ...
# 5768          2021         5.8         6.9
# 5770          2021         7.3         4.0
# 5785          2021         5.1         5.5
# 5796          2021         4.6         6.0
# 5805          2021         8.8        10.0
#
# [1786 rows x 3 columns]

# %%
# Group by year
grouped_df = shows.groupby(["release_year"]).mean()
grouped_df
# Out:
#               imdb_score  tmdb_score
# release_year
# 1969            8.800000    8.300000
# 1972            8.100000    7.000000
# 1981            7.400000    7.400000
# 1982            6.900000    7.500000
# 1983            6.700000    6.700000
# 1984            6.500000    6.600000
# 1987            6.100000    7.300000
# 1989            7.466667    7.533333
# 1992            3.800000    5.000000
# 1993            6.975000    7.275000
# 1994            7.266667    7.600000
# 1995            8.050000    8.300000
# 1996            5.700000    7.300000
# 1997            8.000000    7.900000
# 1998            7.860000    7.940000
# 1999            7.666667    8.100000
# 2000            7.940000    8.020000
# 2001            7.580000    7.840000
# 2002            8.150000    8.075000
# 2003            7.250000    7.175000
# 2004            6.875000    7.575000
# 2005            7.050000    7.287500
# 2006            7.958333    7.675000
# 2007            6.970000    7.970000
# 2008            7.572727    7.645455
# 2009            7.460000    7.600000
# 2010            7.531250    7.468750
# 2011            7.250000    7.507692
# 2012            7.413793    7.365517
# 2013            7.111765    7.682353
# 2014            7.253659    7.336585
# 2015            7.379070    7.497674
# 2016            7.270455    7.409091
# 2017            7.143275    7.393567
# 2018            7.017143    7.394643
# 2019            7.027037    7.687778
# 2020            6.814108    7.580913
# 2021            6.750000    7.441221
# 2022            6.575294    7.225882

# %%
plt.plot(grouped_df.index, grouped_df.imdb_score, label="IMDB Score Avg", linewidth=2, marker='o', markersize=7)
plt.plot(grouped_df.index, grouped_df.tmdb_score, label="TMDB Score Avg", linewidth=2, marker='o', markersize=7, linestyle="--")
plt.xlabel("Year")
plt.ylabel("Average")
plt.legend()
plt.show()

# %% [markdown]
# After 1990 TMDB Avg Score seems to be consistently higher than IMDB Avg Score

# %% [markdown]
# ### Visulize TMDB score spread by year - top 5 years

# %%
years = df_titles.release_year.value_counts().head(5)
years
# Out:
# 2019    848
# 2020    805
# 2018    774
# 2021    758
# 2017    580
# Name: release_year, dtype: int64

# %%
years.index.tolist()
# Out:
# [2019, 2020, 2018, 2021, 2017]

# %%
df_titles_filtered = df_titles[df_titles.release_year.isin(years.index.tolist())]
df_titles_filtered
# Out:
#              id                               title   type  \
# 1824    ts53864                               Ozark   SHOW
# 1825    ts77795                         Derry Girls   SHOW
# 1826    ts56683                          The Sinner   SHOW
# 1827   tm239091                   Blade Runner 2049  MOVIE
# 1828    ts55668                                Dark   SHOW
# ...         ...                                 ...    ...
# 5801  tm1014599                           Fine Wine  MOVIE
# 5802  tm1108171                      Edis Starlight  MOVIE
# 5803  tm1045018                               Clash  MOVIE
# 5804  tm1098060                      Shadow Parties  MOVIE
# 5805   ts271048  Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 1824  A financial adviser drags his family from Chic...          2017
# 1825  Amidst the political conflict of Northern Irel...          2018
# 1826  In a small New York town, a haunted detective ...          2017
# 1827  Thirty years after the events of the first fil...          2017
# 1828  A missing child causes four families to help e...          2017
# ...                                                 ...           ...
# 5801  A beautiful love story that can happen between...          2021
# 5802  Rising star Edis's career journey with ups and...          2021
# 5803  A man from Nigeria returns to his family in Ca...          2021
# 5804  A family faces destruction in a long-running c...          2021
# 5805  With winter behind them, Bheem and his townspe...          2021
#
#      age_certification  runtime                                    genres  \
# 1824             TV-MA       60            ['crime', 'thriller', 'drama']
# 1825             TV-MA       25                                ['comedy']
# 1826             TV-MA       45            ['crime', 'thriller', 'drama']
# 1827                 R      164  ['scifi', 'thriller', 'action', 'drama']
# 1828             TV-MA       56   ['scifi', 'crime', 'drama', 'thriller']
# ...                ...      ...                                       ...
# 5801               NaN      100                      ['romance', 'drama']
# 5802               NaN       74                ['music', 'documentation']
# 5803               NaN       88                       ['family', 'drama']
# 5804               NaN      116                    ['action', 'thriller']
# 5805               NaN        0         ['family', 'comedy', 'animation']
#
#                       production_countries  seasons     imdb_id  imdb_score  \
# 1824                                ['US']      4.0   tt5071412         8.5
# 1825                                ['GB']      3.0   tt7120662         8.4
# 1826                                ['US']      4.0   tt6048596         7.9
# 1827  ['CA', 'HU', 'MX', 'ES', 'GB', 'US']      NaN   tt1856101         8.0
# 1828                                ['DE']      3.0   tt5753856         8.7
# ...                                    ...      ...         ...         ...
# 5801                                ['NG']      NaN  tt13857480         6.9
# 5802                                    []      NaN         NaN         NaN
# 5803                          ['NG', 'CA']      NaN  tt14620732         6.5
# 5804                                    []      NaN  tt10168094         6.2
# 5805                                    []      1.0  tt13711094         8.8
#
#       imdb_votes  tmdb_popularity  tmdb_score
# 1824    278223.0          290.316         8.2
# 1825     28718.0           27.308         8.2
# 1826    117055.0           65.193         7.5
# 1827    539864.0           61.861         7.5
# 1828    354443.0          152.460         8.4
# ...          ...              ...         ...
# 5801        39.0            0.966         NaN
# 5802         NaN            1.036         8.5
# 5803        32.0            0.709         NaN
# 5804         9.0            2.186         NaN
# 5805        16.0            0.979        10.0
#
# [3765 rows x 15 columns]

# %%
sns.violinplot(data=df_titles_filtered, x='release_year', y='tmdb_score');

# %% [markdown]
# from year 2017 to 2021, the avg tmdb score is going up

# %% [markdown]
# ### Create a Facet Grid for movies dataset visualizing tmdb score by genre by year - top  3 years

# %%
years = df_titles[df_titles.type == 'MOVIE'].release_year.value_counts().head(3)
years
# Out:
# 2019    540
# 2020    499
# 2018    473
# Name: release_year, dtype: int64

# %%
df_titles_filtered = df_titles[(df_titles.type == 'MOVIE') & (df_titles.release_year.isin(years.index.tolist()))]
df_titles_filtered
# Out:
#             id                                  title   type  \
# 1829  tm310953                    Sorry to Bother You  MOVIE
# 1836  tm318206                         Den of Thieves  MOVIE
# 1859  tm244364                        The Nightingale  MOVIE
# 1863  tm420745                            How It Ends  MOVIE
# 1868  tm350379                              Ghostland  MOVIE
# ...        ...                                    ...    ...
# 4823  tm921230  Story of Kale: When Someone's in Love  MOVIE
# 4825  tm826983                   The Girl and the Gun  MOVIE
# 4826  tm451269                         Born Beautiful  MOVIE
# 4827  tm840236                                  Milea  MOVIE
# 4828  tm460411                           Stunt School  MOVIE
#
#                                             description  release_year  \
# 1829  In an alternate present-day version of Oakland...          2018
# 1836  A gritty crime saga which follows the lives of...          2018
# 1859  In 1825, Clare, a 21-year-old Irish convict, c...          2018
# 1863  A desperate father tries to return home to his...          2018
# 1868  A mother of two inherits a home from her aunt....          2018
# ...                                                 ...           ...
# 4823  After leaving a toxic relationship, Dinda emba...          2020
# 4825  A department store saleslady has had enough of...          2019
# 4826  After her best friend dies, Barbs starts a new...          2019
# 4827  Years after his teen romance with Milea, a now...          2020
# 4828  An aspiring actress is admitted to a prestigio...          2019
#
#      age_certification  runtime                                       genres  \
# 1829                 R      111      ['fantasy', 'scifi', 'drama', 'comedy']
# 1836                 R      140     ['thriller', 'action', 'crime', 'drama']
# 1859                 R      136              ['thriller', 'drama', 'horror']
# 1863               NaN      113     ['thriller', 'action', 'drama', 'scifi']
# 1868                 R       91  ['horror', 'thriller', 'drama', 'european']
# ...                ...      ...                                          ...
# 4823               NaN       77                         ['drama', 'romance']
# 4825               NaN       80                        ['thriller', 'crime']
# 4826               NaN       96                                   ['comedy']
# 4827               NaN       99                         ['romance', 'drama']
# 4828               NaN       95                                   ['comedy']
#
#      production_countries  seasons     imdb_id  imdb_score  imdb_votes  \
# 1829               ['US']      NaN   tt5688932         6.9     75653.0
# 1836               ['US']      NaN   tt1259528         7.0    107701.0
# 1859               ['AU']      NaN   tt4068576         7.3     28196.0
# 1863         ['CA', 'US']      NaN   tt5246700         5.0     51513.0
# 1868         ['FR', 'CA']      NaN   tt6195094         6.4     30444.0
# ...                   ...      ...         ...         ...         ...
# 4823               ['ID']      NaN  tt13081264         6.4       270.0
# 4825               ['PH']      NaN         NaN         NaN         NaN
# 4826               ['PH']      NaN   tt9364848         5.5       118.0
# 4827               ['ID']      NaN  tt11127878         6.4       547.0
# 4828               ['TR']      NaN   tt9056824         4.4      1123.0
#
#       tmdb_popularity  tmdb_score
# 1829           14.691         6.8
# 1836           55.531         6.7
# 1859           29.689         7.1
# 1863           28.552         5.3
# 1868           67.252         7.4
# ...               ...         ...
# 4823            3.615         7.0
# 4825            1.841         6.1
# 4826            1.867         5.7
# 4827            2.213         5.7
# 4828            1.844         4.0
#
# [1512 rows x 15 columns]

# %%
# Since genre consists of a list of items, considering the first value from the list for this analysis
### This is just one of the ways to get a value from the list, there are other strategies as well to get all the values

import ast

def get_first_value_categories(arr):
    arr = ast.literal_eval(arr)
    
    if len(arr) == 0:
        return np.nan
    
    else:
        return arr[0]
    

df_titles_filtered['genres'] = df_titles_filtered['genres'].apply(get_first_value_categories)
# Out:
# <ipython-input-140-bfa139aabeb2>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_titles_filtered['genres'] = df_titles_filtered['genres'].apply(get_first_value_categories)

# %%
genre_list = df_titles_filtered[df_titles_filtered.type == 'MOVIE'].genres.value_counts().head(3)
genre_list
# Out:
# comedy           391
# drama            357
# documentation    198
# Name: genres, dtype: int64

# %%
df_titles_filtered
# Out:
#             id                                  title   type  \
# 1829  tm310953                    Sorry to Bother You  MOVIE
# 1836  tm318206                         Den of Thieves  MOVIE
# 1859  tm244364                        The Nightingale  MOVIE
# 1863  tm420745                            How It Ends  MOVIE
# 1868  tm350379                              Ghostland  MOVIE
# ...        ...                                    ...    ...
# 4823  tm921230  Story of Kale: When Someone's in Love  MOVIE
# 4825  tm826983                   The Girl and the Gun  MOVIE
# 4826  tm451269                         Born Beautiful  MOVIE
# 4827  tm840236                                  Milea  MOVIE
# 4828  tm460411                           Stunt School  MOVIE
#
#                                             description  release_year  \
# 1829  In an alternate present-day version of Oakland...          2018
# 1836  A gritty crime saga which follows the lives of...          2018
# 1859  In 1825, Clare, a 21-year-old Irish convict, c...          2018
# 1863  A desperate father tries to return home to his...          2018
# 1868  A mother of two inherits a home from her aunt....          2018
# ...                                                 ...           ...
# 4823  After leaving a toxic relationship, Dinda emba...          2020
# 4825  A department store saleslady has had enough of...          2019
# 4826  After her best friend dies, Barbs starts a new...          2019
# 4827  Years after his teen romance with Milea, a now...          2020
# 4828  An aspiring actress is admitted to a prestigio...          2019
#
#      age_certification  runtime    genres production_countries  seasons  \
# 1829                 R      111   fantasy               ['US']      NaN
# 1836                 R      140  thriller               ['US']      NaN
# 1859                 R      136  thriller               ['AU']      NaN
# 1863               NaN      113  thriller         ['CA', 'US']      NaN
# 1868                 R       91    horror         ['FR', 'CA']      NaN
# ...                ...      ...       ...                  ...      ...
# 4823               NaN       77     drama               ['ID']      NaN
# 4825               NaN       80  thriller               ['PH']      NaN
# 4826               NaN       96    comedy               ['PH']      NaN
# 4827               NaN       99   romance               ['ID']      NaN
# 4828               NaN       95    comedy               ['TR']      NaN
#
#          imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1829   tt5688932         6.9     75653.0           14.691         6.8
# 1836   tt1259528         7.0    107701.0           55.531         6.7
# 1859   tt4068576         7.3     28196.0           29.689         7.1
# 1863   tt5246700         5.0     51513.0           28.552         5.3
# 1868   tt6195094         6.4     30444.0           67.252         7.4
# ...          ...         ...         ...              ...         ...
# 4823  tt13081264         6.4       270.0            3.615         7.0
# 4825         NaN         NaN         NaN            1.841         6.1
# 4826   tt9364848         5.5       118.0            1.867         5.7
# 4827  tt11127878         6.4       547.0            2.213         5.7
# 4828   tt9056824         4.4      1123.0            1.844         4.0
#
# [1512 rows x 15 columns]

# %%
df_titles_filtered.dropna(axis=0, subset=['imdb_score', 'tmdb_score'], inplace=True)
df_titles_filtered
# Out:
# <ipython-input-144-ebe24c7e77a1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_titles_filtered.dropna(axis=0, subset=['imdb_score', 'tmdb_score'], inplace=True)
#             id                                  title   type  \
# 1829  tm310953                    Sorry to Bother You  MOVIE
# 1836  tm318206                         Den of Thieves  MOVIE
# 1859  tm244364                        The Nightingale  MOVIE
# 1863  tm420745                            How It Ends  MOVIE
# 1868  tm350379                              Ghostland  MOVIE
# ...        ...                                    ...    ...
# 4822  tm450129                   Sakaling Maging Tayo  MOVIE
# 4823  tm921230  Story of Kale: When Someone's in Love  MOVIE
# 4826  tm451269                         Born Beautiful  MOVIE
# 4827  tm840236                                  Milea  MOVIE
# 4828  tm460411                           Stunt School  MOVIE
#
#                                             description  release_year  \
# 1829  In an alternate present-day version of Oakland...          2018
# 1836  A gritty crime saga which follows the lives of...          2018
# 1859  In 1825, Clare, a 21-year-old Irish convict, c...          2018
# 1863  A desperate father tries to return home to his...          2018
# 1868  A mother of two inherits a home from her aunt....          2018
# ...                                                 ...           ...
# 4822  Two college freshmen, Pol and Laya, accidental...          2019
# 4823  After leaving a toxic relationship, Dinda emba...          2020
# 4826  After her best friend dies, Barbs starts a new...          2019
# 4827  Years after his teen romance with Milea, a now...          2020
# 4828  An aspiring actress is admitted to a prestigio...          2019
#
#      age_certification  runtime    genres production_countries  seasons  \
# 1829                 R      111   fantasy               ['US']      NaN
# 1836                 R      140  thriller               ['US']      NaN
# 1859                 R      136  thriller               ['AU']      NaN
# 1863               NaN      113  thriller         ['CA', 'US']      NaN
# 1868                 R       91    horror         ['FR', 'CA']      NaN
# ...                ...      ...       ...                  ...      ...
# 4822               NaN       90    comedy               ['PH']      NaN
# 4823               NaN       77     drama               ['ID']      NaN
# 4826               NaN       96    comedy               ['PH']      NaN
# 4827               NaN       99   romance               ['ID']      NaN
# 4828               NaN       95    comedy               ['TR']      NaN
#
#          imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 1829   tt5688932         6.9     75653.0           14.691         6.8
# 1836   tt1259528         7.0    107701.0           55.531         6.7
# 1859   tt4068576         7.3     28196.0           29.689         7.1
# 1863   tt5246700         5.0     51513.0           28.552         5.3
# 1868   tt6195094         6.4     30444.0           67.252         7.4
# ...          ...         ...         ...              ...         ...
# 4822   tt9389622         7.1        73.0            1.741         8.0
# 4823  tt13081264         6.4       270.0            3.615         7.0
# 4826   tt9364848         5.5       118.0            1.867         5.7
# 4827  tt11127878         6.4       547.0            2.213         5.7
# 4828   tt9056824         4.4      1123.0            1.844         4.0
#
# [1260 rows x 15 columns]

# %%
plt.rcParams['figure.figsize'] = 10,5

fg = sns.FacetGrid(df_titles_filtered, row='genres', col='release_year', hue='genres')
fg = fg.map(plt.scatter, 'imdb_score', 'tmdb_score')

plt.show()
